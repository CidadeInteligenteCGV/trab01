# %% [markdown]
# # Obtendo dados do database com Pandas

# %% [markdown]
# # Relatório 01

# %% [markdown]
# ### Relatório da frequência geral dos alunos por disciplina, incluindo as seguintes informações: campus onde a disciplina é ofertada, curso a qual a disciplina pertence, código da disciplina, nome da disciplina, horas disciplina, nome do professor, nome do aluno, matrícula do aluno e frequência do aluno na disciplina.

# %% [markdown]
# Código para obtenção do resultado:

# %%
relatorio_01 = pd.read_sql_query("""
                           SELECT C.nome_disciplina, C.cod_disciplina, C.horas_disciplina,  A.campus, B.nome_curso, E.nome_professor, G.nome_aluno, G.cod_matricula, D.presenca
FROM Campus A 
JOIN Curso B ON B.FK_Campus_cod_campus = A.cod_campus
JOIN Disciplina C  ON C.FK_Curso_cod_curso = B.cod_curso
JOIN Historico_Aula D  ON D.FK_Disciplina_cod_disciplina = C.cod_disciplina
JOIN Professor E ON E.cod_servidor = D.FK_Professor_cod_servidor
JOIN Gera F  ON F.FK_Historico_Aula_id_historico_aula = D.id_historico_aula
JOIN Aluno G  ON G.cod_matricula = F.FK_Aluno_cod_matricula
                            """,conn)

# %%
relatorio_01
# Out:
#                              nome_disciplina  cod_disciplina  \
# 0                        Matematica Discreta              23
# 1                          Maquinas de Fluxo              12
# 2                                  Calculo 1               8
# 3                                  Filosofia             229
# 4  Arquitetura e Organizaçao de Computadores             207
# 5  Arquitetura e Organizaçao de Computadores             207
# 6                                Estatistica            1275
# 7                       Historia da educaçao            1908
# 8  Arquitetura e Organizaçao de Computadores             207
# 9                                  Calculo 1               8
#
#    horas_disciplina    campus                          nome_curso  \
# 0                60     Serra              Sistemas de Informação
# 1                60   Aracruz                 Engenharia Mecânica
# 2                90     Serra  Engenharia de Controle e Automação
# 3                30   Vitoria    Licenciatura em Letras/Português
# 4                60     Serra              Sistemas de Informação
# 5                60     Serra              Sistemas de Informação
# 6                60  Colatina                       Administração
# 7                30   Vitoria    Licenciatura em Letras/Português
# 8                60     Serra              Sistemas de Informação
# 9                90     Serra  Engenharia de Controle e Automação
#
#       nome_professor         nome_aluno cod_matricula presenca
# 0          Lara Dias   Leonardo Ribeiro   20162MAT003        P
# 1      Mariana Rocha     Gustavo Santos   20171AUT552        P
# 2      Marisa Castro      Manuela Rocha   20142AUR222        F
# 3         Cauã Souza  Camila Cavalcanti   20151ADM873        P
# 4  Marcos Cavalcanti        Sofia Costa   20181FIS015        F
# 5     Leonardo Souza     Martim Ribeiro   20142MEC188        P
# 6      Diego Almeida  Camila Cavalcanti   20151ADM873        P
# 7     Emilly Ribeiro   Leonardo Ribeiro   20162MAT003        F
# 8     Leonardo Souza   Matilde Ferreira   20182FIS237        P
# 9      Marisa Castro  Camila Cavalcanti   20151ADM873        F

# %% [markdown]
# # Relatorio 02

# %% [markdown]
# ### Relatório da frequência individual do aluno por disciplina, incluindo as seguintes informações: código da disciplina, nome da disciplina, nome do professor, nome do aluno, código de matrícula do aluno, frequência do aluno na disciplina, data da aula, horas disciplina, hora de entrada e saída do aluno.

# %% [markdown]
# codigo para obtenção do resultado:

# %%
relatorio_02 = pd.read_sql_query("""
                            SELECT G.nome_aluno, G.cod_matricula, D.presenca, D.data_aula, C.horas_disciplina, D.horario_inicio, D.horario_saida, C.cod_disciplina, C.nome_disciplina, E.nome_professor
FROM Campus A 
JOIN Curso B ON B.FK_Campus_cod_campus = A.cod_campus
JOIN Disciplina C  ON C.FK_Curso_cod_curso = B.cod_curso
JOIN Historico_Aula D ON D.FK_Disciplina_cod_disciplina = C.cod_disciplina
JOIN Professor E ON E.cod_servidor = D.FK_Professor_cod_servidor
JOIN Gera F  ON F.FK_Historico_Aula_id_historico_aula = D.id_historico_aula
JOIN Aluno G ON G.cod_matricula = F.FK_Aluno_cod_matricula
                            """,conn)

# %%
relatorio_02
# Out:
#           nome_aluno cod_matricula presenca   data_aula  horas_disciplina  \
# 0   Leonardo Ribeiro   20162MAT003        P  2018-08-20                60
# 1     Gustavo Santos   20171AUT552        P  2018-08-21                60
# 2      Manuela Rocha   20142AUR222        F  2018-08-22                90
# 3  Camila Cavalcanti   20151ADM873        P  2018-08-23                30
# 4        Sofia Costa   20181FIS015        F  2018-08-24                60
# 5     Martim Ribeiro   20142MEC188        P  2018-08-25                60
# 6  Camila Cavalcanti   20151ADM873        P  2018-08-26                60
# 7   Leonardo Ribeiro   20162MAT003        F  2018-08-27                30
# 8   Matilde Ferreira   20182FIS237        P  2018-08-28                60
# 9  Camila Cavalcanti   20151ADM873        F  2018-08-29                90
#
#   horario_inicio horario_saida  cod_disciplina  \
# 0       07:50:00      09:30:00              23
# 1       08:20:00      10:00:00              12
# 2       09:50:00      11:30:00               8
# 3       16:10:00      19:00:00             229
# 4       20:00:00      21:00:00             207
# 5       09:50:00      11:20:00             207
# 6       08:20:00      10:00:00            1275
# 7       20:00:00      21:00:00            1908
# 8       08:20:00      09:40:00             207
# 9       18:00:00      21:00:00               8
#
#                              nome_disciplina     nome_professor
# 0                        Matematica Discreta          Lara Dias
# 1                          Maquinas de Fluxo      Mariana Rocha
# 2                                  Calculo 1      Marisa Castro
# 3                                  Filosofia         Cauã Souza
# 4  Arquitetura e Organizaçao de Computadores  Marcos Cavalcanti
# 5  Arquitetura e Organizaçao de Computadores     Leonardo Souza
# 6                                Estatistica      Diego Almeida
# 7                       Historia da educaçao     Emilly Ribeiro
# 8  Arquitetura e Organizaçao de Computadores     Leonardo Souza
# 9                                  Calculo 1      Marisa Castro

# %% [markdown]
# ## Relatório 03

# %% [markdown]
# ### Relatório geral de dados dos alunos por disciplina, incluindo as seguintes informações: código da disciplina, nome da disciplina, horas disciplina, nome do professor, campus onde a disciplina é ofertada, curso da disciplina ofertada, nome do aluno, matrícula do aluno, curso do aluno.

# %% [markdown]
# codigo para obtenção do resultado:

# %%
relatorio_03 = pd.read_sql_query("""
                       SELECT C.cod_disciplina, C.nome_disciplina, C.horas_disciplina, E.nome_professor, A.campus, B.nome_curso, G.nome_aluno, G.cod_matricula
FROM Campus A 
JOIN Curso B ON B.FK_Campus_cod_campus = A.cod_campus
JOIN Disciplina C ON C.FK_Curso_cod_curso = B.cod_curso
JOIN Historico_Aula D ON D.FK_Disciplina_cod_disciplina = C.cod_disciplina
JOIN Professor E ON E.cod_servidor = D.FK_Professor_cod_servidor
JOIN Gera F ON F.FK_Historico_Aula_id_historico_aula = D.id_historico_aula
JOIN Aluno G ON G.cod_matricula = F.FK_Aluno_cod_matricula
                            """,conn)

# %%
relatorio_03
# Out:
#    cod_disciplina                            nome_disciplina  \
# 0              23                        Matematica Discreta
# 1              12                          Maquinas de Fluxo
# 2               8                                  Calculo 1
# 3             229                                  Filosofia
# 4             207  Arquitetura e Organizaçao de Computadores
# 5             207  Arquitetura e Organizaçao de Computadores
# 6            1275                                Estatistica
# 7            1908                       Historia da educaçao
# 8             207  Arquitetura e Organizaçao de Computadores
# 9               8                                  Calculo 1
#
#    horas_disciplina     nome_professor    campus  \
# 0                60          Lara Dias     Serra
# 1                60      Mariana Rocha   Aracruz
# 2                90      Marisa Castro     Serra
# 3                30         Cauã Souza   Vitoria
# 4                60  Marcos Cavalcanti     Serra
# 5                60     Leonardo Souza     Serra
# 6                60      Diego Almeida  Colatina
# 7                30     Emilly Ribeiro   Vitoria
# 8                60     Leonardo Souza     Serra
# 9                90      Marisa Castro     Serra
#
#                            nome_curso         nome_aluno cod_matricula
# 0              Sistemas de Informação   Leonardo Ribeiro   20162MAT003
# 1                 Engenharia Mecânica     Gustavo Santos   20171AUT552
# 2  Engenharia de Controle e Automação      Manuela Rocha   20142AUR222
# 3    Licenciatura em Letras/Português  Camila Cavalcanti   20151ADM873
# 4              Sistemas de Informação        Sofia Costa   20181FIS015
# 5              Sistemas de Informação     Martim Ribeiro   20142MEC188
# 6                       Administração  Camila Cavalcanti   20151ADM873
# 7    Licenciatura em Letras/Português   Leonardo Ribeiro   20162MAT003
# 8              Sistemas de Informação   Matilde Ferreira   20182FIS237
# 9  Engenharia de Controle e Automação  Camila Cavalcanti   20151ADM873

# %% [markdown]
# ## Relatório 04

# %% [markdown]
# ### Relatório de reprovação por falta na disciplina, incluindo as seguintes informações: código da disciplina, nome da disciplina, horas disciplina, nome do professor, campus onde a disciplina foi ofertada, matrícula do aluno, frequência do aluno que reprovou por falta na disciplina.

# %% [markdown]
# codigo para obtenção do resultado:

# %%
relatorio_04 = pd.read_sql_query("""
                            SELECT C.cod_disciplina, C.horas_disciplina, E.nome_professor, A.campus, G.nome_aluno AS Aluno_reprovado, G.cod_matricula, D.presenca
FROM Campus A 
JOIN Curso B ON B.FK_Campus_cod_campus = A.cod_campus
JOIN Disciplina C ON C.FK_Curso_cod_curso = B.cod_curso
JOIN Historico_Aula D ON D.FK_Disciplina_cod_disciplina = C.cod_disciplina
JOIN Professor E ON E.cod_servidor = D.FK_Professor_cod_servidor
JOIN Gera F ON F.FK_Historico_Aula_id_historico_aula = D.id_historico_aula
JOIN Aluno G ON G.cod_matricula = F.FK_Aluno_cod_matricula
WHERE  D.presenca= 'F'
                            """,conn)

# %%
relatorio_04
# Out:
#    cod_disciplina  horas_disciplina     nome_professor   campus  \
# 0               8                90      Marisa Castro    Serra
# 1             207                60  Marcos Cavalcanti    Serra
# 2            1908                30     Emilly Ribeiro  Vitoria
# 3               8                90      Marisa Castro    Serra
#
#      aluno_reprovado cod_matricula presenca
# 0      Manuela Rocha   20142AUR222        F
# 1        Sofia Costa   20181FIS015        F
# 2   Leonardo Ribeiro   20162MAT003        F
# 3  Camila Cavalcanti   20151ADM873        F

# %% [markdown]
# ## Relatório 05

# %% [markdown]
# ### Relatório de frequência nas disciplinas ofertadas por professor, incluindo as seguintes informações: código do servidor, nome do professor, código da disciplina, nome da disciplina, horas disciplina, campus onde a disciplina foi ofertada, média de frequência dos alunos, média de reprovação por falta.

# %% [markdown]
# codigo para obtenção do resultado:

# %%
relatorio_05 = pd.read_sql_query("""
                            SELECT E.cod_servidor, E.nome_professor, C.cod_disciplina, C.nome_disciplina, C.horas_disciplina, A.campus, G.nome_aluno AS Aluno_reprovado, D.presenca
FROM Campus A 
JOIN Curso B ON B.FK_Campus_cod_campus = A.cod_campus
JOIN Disciplina C ON C.FK_Curso_cod_curso = B.cod_curso
JOIN Historico_Aula D ON D.FK_Disciplina_cod_disciplina = C.cod_disciplina
JOIN Professor E ON E.cod_servidor = D.FK_Professor_cod_servidor
JOIN Gera F ON F.FK_Historico_Aula_id_historico_aula = D.id_historico_aula
JOIN Aluno G ON G.cod_matricula = F.FK_Aluno_cod_matricula
WHERE  D.presenca= 'F'

                            """,conn)

# %%
relatorio_05
# Out:
#   cod_servidor     nome_professor  cod_disciplina  \
# 0  2007IFES023      Marisa Castro               8
# 1  2000IFES128  Marcos Cavalcanti             207
# 2  1999IFES005     Emilly Ribeiro            1908
# 3  2007IFES023      Marisa Castro               8
#
#                              nome_disciplina  horas_disciplina   campus  \
# 0                                  Calculo 1                90    Serra
# 1  Arquitetura e Organizaçao de Computadores                60    Serra
# 2                       Historia da educaçao                30  Vitoria
# 3                                  Calculo 1                90    Serra
#
#      aluno_reprovado presenca
# 0      Manuela Rocha        F
# 1        Sofia Costa        F
# 2   Leonardo Ribeiro        F
# 3  Camila Cavalcanti        F

# %% [markdown]
# ## Relatório 06

# %% [markdown]
# ### Relatório de todas as disciplinas ofertadas por campus, incluindo as seguintes informações: código da disciplina, nome da disciplina, horas disciplina, nome do professor, curso onde a disciplina está alocada, campus onde a disciplina é ofertada.

# %% [markdown]
# codigo para obtenção do resultado:

# %%
relatorio_06 = pd.read_sql_query("""
                            SELECT C.cod_disciplina, C.nome_disciplina, C.horas_disciplina, D.horario_inicio, B.nome_curso , A.campus, E.nome_professor
FROM Campus A 
JOIN Curso B ON B.FK_Campus_cod_campus = A.cod_campus
JOIN Disciplina C ON C.FK_Curso_cod_curso = B.cod_curso
JOIN Historico_Aula D ON D.FK_Disciplina_cod_disciplina = C.cod_disciplina
JOIN Professor E ON E.cod_servidor = D.FK_Professor_cod_servidor
JOIN Gera F ON F.FK_Historico_Aula_id_historico_aula = D.id_historico_aula
JOIN Aluno G ON G.cod_matricula = F.FK_Aluno_cod_matricula
                            """,conn)

# %%
relatorio_06
# Out:
#    cod_disciplina                            nome_disciplina  \
# 0              23                        Matematica Discreta
# 1              12                          Maquinas de Fluxo
# 2               8                                  Calculo 1
# 3             229                                  Filosofia
# 4             207  Arquitetura e Organizaçao de Computadores
# 5             207  Arquitetura e Organizaçao de Computadores
# 6            1275                                Estatistica
# 7            1908                       Historia da educaçao
# 8             207  Arquitetura e Organizaçao de Computadores
# 9               8                                  Calculo 1
#
#    horas_disciplina horario_inicio                          nome_curso  \
# 0                60       07:50:00              Sistemas de Informação
# 1                60       08:20:00                 Engenharia Mecânica
# 2                90       09:50:00  Engenharia de Controle e Automação
# 3                30       16:10:00    Licenciatura em Letras/Português
# 4                60       20:00:00              Sistemas de Informação
# 5                60       09:50:00              Sistemas de Informação
# 6                60       08:20:00                       Administração
# 7                30       20:00:00    Licenciatura em Letras/Português
# 8                60       08:20:00              Sistemas de Informação
# 9                90       18:00:00  Engenharia de Controle e Automação
#
#      campus     nome_professor
# 0     Serra          Lara Dias
# 1   Aracruz      Mariana Rocha
# 2     Serra      Marisa Castro
# 3   Vitoria         Cauã Souza
# 4     Serra  Marcos Cavalcanti
# 5     Serra     Leonardo Souza
# 6  Colatina      Diego Almeida
# 7   Vitoria     Emilly Ribeiro
# 8     Serra     Leonardo Souza
# 9     Serra      Marisa Castro
